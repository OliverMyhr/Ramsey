# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

print(fda.statistics())
# Out:
#                                             mean  median        std   min  \
# sourceId elementId           unit
# Blindern air_temperature     degC       0.523089     0.9   8.436512 -20.3
#          relative_humidity   percent   80.509669    84.0  12.215273  27.0
#          wind_from_direction degrees   87.188766    39.0  95.600459   0.0
# Tromsø   air_temperature     degC      -0.641920    -0.2   6.131843 -16.4
#          relative_humidity   percent   79.401243    82.0  12.179179  31.0
#          wind_from_direction degrees  178.590813   193.0  74.745882   0.0
#
#                                         max  count
# sourceId elementId           unit
# Blindern air_temperature     degC      22.4   4344
#          relative_humidity   percent   98.0   4344
#          wind_from_direction degrees  360.0   4344
# Tromsø   air_temperature     degC      14.7   4344
#          relative_humidity   percent   96.0   4344
#          wind_from_direction degrees  360.0   4245

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

print(fda.pivot_data())
# Out:
# elementId                   air_temperature  relative_humidity  \
# referenceTime
# 2009-09-01 00:00:00.000000            13.50               90.0
# 2009-09-01 01:00:00.000000            13.65               89.0
# 2009-09-01 02:00:00.000000            13.70               88.0
# 2009-09-01 03:00:00.000000            13.45               90.0
# 2009-09-01 04:00:00.000000            13.45               91.5
# ...                                     ...                ...
# 2010-02-28 19:00:00.000000            -6.25               83.0
# 2010-02-28 20:00:00.000000            -6.25               83.0
# 2010-02-28 21:00:00.000000            -6.40               82.0
# 2010-02-28 22:00:00.000000            -6.35               82.0
# 2010-02-28 23:00:00.000000            -6.40               80.0
#
# elementId                   wind_from_direction
# referenceTime
# 2009-09-01 00:00:00.000000                184.5
# 2009-09-01 01:00:00.000000                184.0
# ...

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

print(fda.relation_analysis())
# Out:
# Skala mellom -1 og 1, der 1 betyr sterk sammenheng, tall nærmere 0 betyr svak sammenheng.
#
# elementId            air_temperature  relative_humidity  wind_from_direction
# elementId
# air_temperature             1.000000          -0.069959             0.330082
# relative_humidity          -0.069959           1.000000            -0.130380
# wind_from_direction         0.330082          -0.130380             1.000000

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

fda.relation_analysis_plots()

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

print(fda.find_outliers())
# Out:
# Antall avvik: 1166
#
#                     referenceTime  sourceId            elementId  avg_value  \
# 80     2009-09-01 13:00:00.000000  Blindern  wind_from_direction      225.0
# 86     2009-09-01 14:00:00.000000  Blindern  wind_from_direction      241.0
# 92     2009-09-01 15:00:00.000000  Blindern  wind_from_direction      225.0
# 104    2009-09-01 17:00:00.000000  Blindern  wind_from_direction      239.0
# 110    2009-09-01 18:00:00.000000  Blindern  wind_from_direction      239.0
# ...                           ...       ...                  ...        ...
# 25904  2010-02-28 13:00:00.000000    Tromsø  wind_from_direction      237.0
# 25916  2010-02-28 15:00:00.000000    Tromsø  wind_from_direction      227.0
# 25928  2010-02-28 17:00:00.000000    Tromsø  wind_from_direction      230.0
# 25934  2010-02-28 18:00:00.000000    Tromsø  wind_from_direction      247.0
# 25946  2010-02-28 20:00:00.000000    Tromsø  wind_from_direction      247.0
#
#           unit
# 80     degrees
# ...

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_analysis as fda

fda.final_df_plots()

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_to_json_visual as ftjv

ftjv.polar_plot()

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_to_json_visual as ftjv

ftjv.plot_monthly_average()

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_to_json_visual as ftjv

ftjv.heatmap_weekday_hour()
