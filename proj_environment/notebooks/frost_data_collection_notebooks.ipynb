# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_collection as f


print(f.understand_structure())
# Out:
# dict_keys(['@context', '@type', 'apiVersion', 'license', 'createdAt', 'queryTime', 'currentItemCount', 'itemsPerPage', 'offset', 'totalItemCount', 'currentLink', 'data'])
# {
#      "@context": "https://frost.met.no/schema",
#      "@type": "ObservationResponse",
#      "apiVersion": "v0",
#      "license": "https://creativecommons.org/licenses/by/3.0/no/",
#      "createdAt": "2025-04-18T17:08:50Z",
#      "queryTime": 0.242,
#      "currentItemCount": 288,
#      "itemsPerPage": 288,
#      "offset": 0,
#      "totalItemCount": 288,
#      "currentLink": "https://frost.met.no/observations/v0.jsonld?sources=SN68090&elements=air_temperature%2C+wind_from_direction&referencetime=2025-03-01%2F2025-03-03",
#      "data": [
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 108,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 154,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 89,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T00:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 143,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 145,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 68,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T01:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 189,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 134,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 97,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 5
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T02:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 205,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 179,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 5
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 158,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 151,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 169,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T03:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.9,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 178,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 145,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 152,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 172,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 99,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T04:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 121,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T05:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.9,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 204,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T05:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 169,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T05:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 171,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T05:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 173,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-01T05:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 0.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 170,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
# ...
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T22:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 166,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T22:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 165,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T22:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 152,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T22:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 138,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 125,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 124,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.9,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 140,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 4.9,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 154,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 150,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-03-02T23:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": 5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "wind_from_direction",
#                          "value": 148,
#                          "unit": "degrees",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 10
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     }
#                ]
#           }
#      ]
# }

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_collection as f

print(f.to_df())
# Out:
#                   referenceTime   sourceId            elementId  value  \
# 0     2009-09-01 00:00:00+00:00  SN18700:0    relative_humidity   92.0
# 1     2009-09-01 00:00:00+00:00  SN18700:0      air_temperature   16.5
# 2     2009-09-01 00:00:00+00:00  SN18700:0  wind_from_direction  178.0
# 3     2009-09-01 01:00:00+00:00  SN18700:0    relative_humidity   92.0
# 4     2009-09-01 01:00:00+00:00  SN18700:0      air_temperature   16.6
# ...                         ...        ...                  ...    ...
# 25960 2010-02-28 22:00:00+00:00  SN90450:0      air_temperature  -10.8
# 25961 2010-02-28 22:00:00+00:00  SN90450:0  wind_from_direction  194.0
# 25962 2010-02-28 23:00:00+00:00  SN90450:0    relative_humidity   86.0
# 25963 2010-02-28 23:00:00+00:00  SN90450:0      air_temperature  -11.0
# 25964 2010-02-28 23:00:00+00:00  SN90450:0  wind_from_direction  177.0
#
#           unit
# 0      percent
# 1         degC
# 2      degrees
# 3      percent
# 4         degC
# ...        ...
# 25960     degC
# 25961  degrees
# 25962  percent
# 25963     degC
# 25964  degrees
#
# [25965 rows x 5 columns]

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_data_collection as f

print(f.final_data())
# Out:
#                     referenceTime  sourceId            elementId  avg_value  \
# 0      2009-09-01 00:00:00.000000  Blindern      air_temperature       16.5
# 1      2009-09-01 00:00:00.000000  Blindern    relative_humidity       92.0
# 2      2009-09-01 00:00:00.000000  Blindern  wind_from_direction      178.0
# 3      2009-09-01 00:00:00.000000    Tromsø      air_temperature       10.5
# 4      2009-09-01 00:00:00.000000    Tromsø    relative_humidity       88.0
# ...                           ...       ...                  ...        ...
# 25960  2010-02-28 23:00:00.000000  Blindern    relative_humidity       74.0
# 25961  2010-02-28 23:00:00.000000  Blindern  wind_from_direction       20.0
# 25962  2010-02-28 23:00:00.000000    Tromsø      air_temperature      -11.0
# 25963  2010-02-28 23:00:00.000000    Tromsø    relative_humidity       86.0
# 25964  2010-02-28 23:00:00.000000    Tromsø  wind_from_direction      177.0
#
#           unit
# 0         degC
# 1      percent
# 2      degrees
# 3         degC
# 4      percent
# ...        ...
# 25960  percent
# 25961  degrees
# 25962     degC
# 25963  percent
# 25964  degrees
#
# [25965 rows x 5 columns]
