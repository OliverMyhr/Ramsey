# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_pred_analysis as fpa

fpa.visualize_reg()
# Out:
# Feil oppsto for Vindhastighet: For få punkter

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_pred_analysis as fpa

fpa.temperature_plot()

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost_pred_analysis as fpa

fpa.humidity_plot()
