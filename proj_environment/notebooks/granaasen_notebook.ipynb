# %%
# Understand structure

import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import granaasen_data as g

g.understand_structure()
# Out:
# dict_keys(['@context', '@type', 'apiVersion', 'license', 'createdAt', 'queryTime', 'currentItemCount', 'itemsPerPage', 'offset', 'totalItemCount', 'currentLink', 'data'])
# {
#      "@context": "https://frost.met.no/schema",
#      "@type": "ObservationResponse",
#      "apiVersion": "v0",
#      "license": "https://creativecommons.org/licenses/by/3.0/no/",
#      "createdAt": "2025-03-26T19:46:54Z",
#      "queryTime": 0.292,
#      "currentItemCount": 288,
#      "itemsPerPage": 288,
#      "offset": 0,
#      "totalItemCount": 288,
#      "currentLink": "https://frost.met.no/observations/v0.jsonld?sources=SN68090&elements=air_temperature%2C+mean%28air_temperature+P1D%29%2C+sum%28precipitation_amount+P1D%29%2C+mean%28wind_speed+P1D%29&referencetime=2025-02-02%2F2025-02-04",
#      "data": [
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "sum(precipitation_amount P1D)",
#                          "value": 0,
#                          "unit": "mm",
#                          "timeOffset": "PT18H",
#                          "timeResolution": "P1D",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2"
#                     },
#                     {
#                          "elementId": "sum(precipitation_amount P1D)",
#                          "value": 0,
#                          "unit": "mm",
#                          "timeOffset": "PT6H",
#                          "timeResolution": "P1D",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "2",
#                          "qualityCode": 0
#                     },
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T00:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T01:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T02:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T03:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T04:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T05:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.8,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.9,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T06:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.5,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T07:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.6,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -7,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -6.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-02T08:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -5.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
# ...
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T21:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.1,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T22:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:00:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:10:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.4,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:20:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:30:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:40:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.2,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           },
#           {
#                "sourceId": "SN68090:0",
#                "referenceTime": "2025-02-03T23:50:00.000Z",
#                "observations": [
#                     {
#                          "elementId": "air_temperature",
#                          "value": -0.3,
#                          "unit": "degC",
#                          "level": {
#                               "levelType": "height_above_ground",
#                               "unit": "m",
#                               "value": 2
#                          },
#                          "timeOffset": "PT0H",
#                          "timeResolution": "PT10M",
#                          "timeSeriesId": 0,
#                          "performanceCategory": "C",
#                          "exposureCategory": "4",
#                          "qualityCode": 0
#                     }
#                ]
#           }
#      ]
# }

# %%
# SetUp
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import granaasen_data as g

g.setUp_file()
# Out:
#      sted                 tidspunkt  sum(precipitation_amount P1D)  \
# 0          2025-02-01T00:00:00.000Z                            2.5
# 1          2025-02-01T00:10:00.000Z                            NaN
# 2          2025-02-01T00:20:00.000Z                            NaN
# 3          2025-02-01T00:30:00.000Z                            NaN
# 4          2025-02-01T00:40:00.000Z                            NaN
# ...   ...                       ...                            ...
# 4006       2025-02-28T23:10:00.000Z                            NaN
# 4007       2025-02-28T23:20:00.000Z                            NaN
# 4008       2025-02-28T23:30:00.000Z                            NaN
# 4009       2025-02-28T23:40:00.000Z                            NaN
# 4010       2025-02-28T23:50:00.000Z                            NaN
#
#       air_temperature  mean(air_temperature P1D)
# 0                -1.5                        NaN
# 1                -1.5                        NaN
# 2                -1.7                        NaN
# 3                -1.9                        NaN
# 4                -1.7                        NaN
# ...               ...                        ...
# 4006              2.1                        NaN
# 4007              1.9                        NaN
# 4008              1.9                        NaN
# 4009              1.9                        NaN
# 4010              1.8                        NaN
#
# [4011 rows x 5 columns]
#      sted                 tidspunkt  air_temperature  \
# 0          2025-02-01T00:00:00.000Z             -1.5
# 1          2025-02-01T00:10:00.000Z             -1.5
# 2          2025-02-01T00:20:00.000Z             -1.7
# 3          2025-02-01T00:30:00.000Z             -1.9
# 4          2025-02-01T00:40:00.000Z             -1.7
# ...   ...                       ...              ...
# 4006       2025-02-28T23:10:00.000Z              2.1
# 4007       2025-02-28T23:20:00.000Z              1.9
# 4008       2025-02-28T23:30:00.000Z              1.9
# 4009       2025-02-28T23:40:00.000Z              1.9
# 4010       2025-02-28T23:50:00.000Z              1.8
#
#       sum(precipitation_amount P1D)  mean(air_temperature P1D)
# 0                               2.5                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 4006                            NaN                        NaN
# 4007                            NaN                        NaN
# 4008                            NaN                        NaN
# 4009                            NaN                        NaN
# 4010                            NaN                        NaN
#
# [4011 rows x 5 columns]
