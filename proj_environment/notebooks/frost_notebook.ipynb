# %%
# Understand structure

import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost as f

f.understand_structure()
# Out:
# dict_keys(['@context', '@type', 'apiVersion', 'license', 'createdAt', 'queryTime', 'currentItemCount', 'itemsPerPage', 'offset', 'totalItemCount', 'currentLink', 'data'])
# {
#           "@context": "https://frost.met.no/schema",
#           "@type": "ObservationResponse",
#           "apiVersion": "v0",
#           "license": "https://creativecommons.org/licenses/by/3.0/no/",
#           "createdAt": "2025-03-27T20:51:01Z",
#           "queryTime": 0.336,
#           "currentItemCount": 288,
#           "itemsPerPage": 288,
#           "offset": 0,
#           "totalItemCount": 288,
#           "currentLink": "https://frost.met.no/observations/v0.jsonld?sources=SN18700&sources=SN68090&elements=relative_humidity%2C+air_temperature%2C+max%28rainfall_rate+PT1M%29%2C+wind_from_direction&referencetime=2018-02-02%2F2018-02-04",
#           "data": [
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:00:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "relative_humidity",
#                                                   "value": 71,
#                                                   "unit": "percent",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -3.9,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 2
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -3.8,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 25,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 25,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:10:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 26,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:20:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 25,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:30:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 25,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:40:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 18,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T00:50:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 14,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:00:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "relative_humidity",
#                                                   "value": 71,
#                                                   "unit": "percent",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -4.4,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 2
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -4.4,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:10:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 21,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:20:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 27,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:30:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 23,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:40:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 19,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T01:50:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 20,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:00:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "relative_humidity",
#                                                   "value": 68,
#                                                   "unit": "percent",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -5,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 2
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -5,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:10:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 14,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:20:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 18,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:30:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:40:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 18,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T02:50:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 17,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T03:00:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "relative_humidity",
#                                                   "value": 68,
#                                                   "unit": "percent",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -5.4,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 2
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -5.5,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 15,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 15,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T03:10:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 11,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T03:20:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 10,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-02T03:30:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 6,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
# ...
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T22:40:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 11,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T22:50:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 8,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:00:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "relative_humidity",
#                                                   "value": 71,
#                                                   "unit": "percent",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -8.6,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 2
#                                         },
#                                         {
#                                                   "elementId": "air_temperature",
#                                                   "value": -8.6,
#                                                   "unit": "degC",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 2
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "1",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 11,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT1H",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         },
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 11,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:10:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 14,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:20:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 7,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:30:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 13,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:40:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 14,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     },
#                     {
#                               "sourceId": "SN18700:0",
#                               "referenceTime": "2018-02-03T23:50:00.000Z",
#                               "observations": [
#                                         {
#                                                   "elementId": "wind_from_direction",
#                                                   "value": 13,
#                                                   "unit": "degrees",
#                                                   "level": {
#                                                             "levelType": "height_above_ground",
#                                                             "unit": "m",
#                                                             "value": 10
#                                                   },
#                                                   "timeOffset": "PT0H",
#                                                   "timeResolution": "PT10M",
#                                                   "timeSeriesId": 0,
#                                                   "performanceCategory": "C",
#                                                   "exposureCategory": "2",
#                                                   "qualityCode": 0
#                                         }
#                               ]
#                     }
#           ]
# }

# %%
# SetUp
import os
import sys
from dotenv import load_dotenv

load_dotenv("../src/.env")

src_path = os.path.abspath("../src")
sys.path.append(src_path)

import frost as f


f.setUp_file()
# Out:
#                  elementId  value     unit  \
# 0        relative_humidity   88.0  percent
# 1        relative_humidity   88.0  percent
# 2          air_temperature   -5.6     degC
# 3          air_temperature   -5.6     degC
# 4          air_temperature   -5.6     degC
# ...                    ...    ...      ...
# 12575  wind_from_direction  225.0  degrees
# 12576    relative_humidity  100.0  percent
# 12577      air_temperature    1.2     degC
# 12578      air_temperature    1.1     degC
# 12579  wind_from_direction  227.0  degrees
#
#                                                    level timeOffset  \
# 0      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 2      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 4      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 12575  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 12576  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 12577  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 12578  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 12579  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#       timeResolution  timeSeriesId performanceCategory exposureCategory  \
# 0               PT1M             0                   C                1
# 1               PT1H             0                   C                1
# 2              PT10M             0                   C                1
# 3               PT1M             0                   C                1
# 4               PT1H             0                   C                1
# ...              ...           ...                 ...              ...
# 12575           PT1M             0                   C                2
# 12576           PT1M             0                   C                1
# 12577          PT10M             0                   C                1
# 12578           PT1M             0                   C                1
# 12579           PT1M             0                   C                2
#
#        qualityCode             referenceTime   sourceId
# 0              0.0  2025-02-02T00:00:00.000Z  SN18700:0
# 1              0.0  2025-02-02T00:00:00.000Z  SN18700:0
# 2              2.0  2025-02-02T00:00:00.000Z  SN18700:0
# 3              0.0  2025-02-02T00:00:00.000Z  SN18700:0
# 4              2.0  2025-02-02T00:00:00.000Z  SN18700:0
# ...            ...                       ...        ...
# 12575          0.0  2025-02-03T23:58:00.000Z  SN18700:0
# 12576          0.0  2025-02-03T23:59:00.000Z  SN18700:0
# 12577          2.0  2025-02-03T23:59:00.000Z  SN18700:0
# 12578          0.0  2025-02-03T23:59:00.000Z  SN18700:0
# 12579          0.0  2025-02-03T23:59:00.000Z  SN18700:0
#
# [12580 rows x 12 columns]
